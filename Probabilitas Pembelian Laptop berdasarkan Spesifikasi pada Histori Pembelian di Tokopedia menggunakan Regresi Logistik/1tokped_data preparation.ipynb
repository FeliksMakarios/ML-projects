# %% [markdown]
# #**EDA : Harga Laptop di Tokopedia**

# %% [markdown]
# Dataset diambil dari `E-commerce Laptop Price Scraping - Laptop Price from Indonesia E-Commerce` oleh Arta Kusuma. Dataset ini berisi harga laptop dari beberapa aplikasi e-commerce seperti Shoope dan Tokopedia. Harga laptop yang dihimpun berasal dari Oktober 2020-Januari 2021.
#
# Eksplorasi ini akan menggunakan data dari aplikasi e-commerce Tokopedia pada Januari 2021 saja.
#
# Dataset : https://www.kaggle.com/artakusuma/laptopecomercee

# %%
#Mengkoneksikan Drive pada Colab

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import os
import glob

# %% [markdown]
# ##**Mempersiapkan Data**

# %% [markdown]
# ###Menggabungkan semua file csv pada direktori menjadi satu file

# %% [markdown]
# ####Data Oktober 2020

# %%
#Pilih direktori 2020_Oktober
os.chdir("/content/drive/My Drive/Dataset/Laptop_Price_List_Tokopedia/Tokped/2020_Oktober")

# %% [markdown]
# ##### Ini bisa dilewati jika sudah pernah digabungkan semua datanya

# %%
#Mengambil semua file dengan ekstensi .csv
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#Mengkombinasikan semua file .csv
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

#Lalu hasilnya diexport menjadi satu file .csv
combined_csv.to_csv( "october2020.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ##### Tampilkan data hasil penggabungan untuk Oktober 2020

# %%
#Hasil penggabungan dijadikan dataframe dengan nama laptop
okt = pd.read_csv('october2020.csv')
okt
# Out:
#                                                      name  ...        date
# 0       ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ...  02-10-2020
# 1       Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ...  02-10-2020
# 2       LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ...  02-10-2020
# 3       Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ...  02-10-2020
# 4       PC All In One acer Aspire C24-960 8GB 1TB Core...  ...  02-10-2020
# ...                                                   ...  ...         ...
# 100876                 MSI GF63 Thin 9SC / 9S7-16R312-621  ...  06-10-2020
# 100877  NOTEBOOK MSI GF63 9SCSR (9S7-16R412-883) INTEL...  ...  06-10-2020
# 100878  MSI GF63 9SC i5-9300HQ GTX 1650 Ram 8GB SSD 25...  ...  06-10-2020
# 100879      Notebook MSI 9S7-16R312-024 GF63 9SC i7-9750H  ...  06-10-2020
# 100880  MSI GF63 Slim Gaming Laptop i7 Gen9 GTX 1650 I...  ...  06-10-2020
#
# [100881 rows x 6 columns]

# %% [markdown]
# ####Data November 2020

# %%
#Pilih direktori 2020_Oktober
os.chdir("/content/drive/My Drive/Dataset/Laptop_Price_List_Tokopedia/Tokped/2020_November")

# %% [markdown]
# ##### Ini bisa dilewati jika sudah pernah digabungkan semua datanya

# %%
#Mengambil semua file dengan ekstensi .csv
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#Mengkombinasikan semua file .csv
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

#Lalu hasilnya diexport menjadi satu file .csv
combined_csv.to_csv( "november2020.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ##### Tampilkan data hasil penggabungan untuk November 2020

# %%
#Hasil penggabungan dijadikan dataframe dengan nama laptop
nov = pd.read_csv('november2020.csv')
nov
# Out:
#                                                    name  ...        date
# 0     ACER ASPIRE 5 A514-53 i3-1005G1 4GB 512GB SSD ...  ...  30-11-2020
# 1     Acer Aspire 3 A315 AMD RYZEN 3 3200 8GB HDD 50...  ...  30-11-2020
# 2     LAPTOP ACER ASPIRE 3 CELERON N4120 256GB SSD W...  ...  30-11-2020
# 3     ACER ASPIRE 3 A314 RYZEN 3-3250|8GB|256GB SSD|...  ...  30-11-2020
# 4     ACER ASPIRE 3 A315-42 AMD RYZEN 3-3200U RAM 8G...  ...  30-11-2020
# ...                                                 ...  ...         ...
# 7204  Asus ROG Phone 2 12/512GB Resmi Tam Fullset Mu...  ...  27-11-2020
# 7205  ASUS ROG GL503GE # i7-8750 6CORE 120HZ 16gb SS...  ...  27-11-2020
# 7206      New Product Asus ROG F553VD, GTX1050 2GB DDr5  ...  27-11-2020
# 7207  ASUS ROG GL552VX-DM229D I7 | 8GB | 1TB | GTX 9...  ...  27-11-2020
# 7208  ASUS ROG 2 II PHONE 12GB 1TB 1 Terabyte 1000GB...  ...  27-11-2020
#
# [7209 rows x 6 columns]

# %% [markdown]
# ####Data Januari 2021

# %%
#Pilih direktori 2020_Oktober
os.chdir("/content/drive/My Drive/Dataset/Laptop_Price_List_Tokopedia/Tokped/2021_Januari")

# %%
#Hasil penggabungan dijadikan dataframe dengan nama laptop
jan = pd.read_csv('january2021.csv')
jan
# Out:
#                                                     name  ...        date
# 0      Laptop Asus Vivobook A416JA BV311TS i3 1005G1 ...  ...  16-01-2021
# 1      Asus Vivobook K413EQ GeForce® MX350 - i7 1165G...  ...  16-01-2021
# 2      ASUS Vivobook A416JA BV311TS i3 1005G1 4G 1TB ...  ...  16-01-2021
# 3      Asus Vivobook K413EQ 14" FHD Core i7-1165G7 8G...  ...  16-01-2021
# 4      LAPTOP ASUS VIVOBOOK K413FQ i5-10210U 8GB 512G...  ...  16-01-2021
# ...                                                  ...  ...         ...
# 42593  ASUS VIVOBOOK FLIP TM420IA RYZEN 5-4500U 8GB 5...  ...  26-01-2021
# 42594  Laptop Asus Vivobook K413FQ i5 8gb 512Gb 14fhd...  ...  26-01-2021
# 42595  Asus vivobook A416ma intel N4020 4gb 256gb 14 ...  ...  26-01-2021
# 42596  ASUS VIVOBOOK A407UF I5 8250U 4GB 256GB MX130 ...  ...  26-01-2021
# 42597  LAPTOP ASUS VIVOBOOK K413EQ I7-1165G7 8GB 512G...  ...  26-01-2021
#
# [42598 rows x 6 columns]

# %% [markdown]
# ####Menggabungkan Ketiga Dataframe

# %%
# Menggabungkan (concatenate) dua dataframe (okt dan nov) dengan mengabaikan index
oknov = pd.concat([okt, nov], ignore_index=True, sort=False)
oknov
# Out:
#                                                      name  ...        date
# 0       ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ...  02-10-2020
# 1       Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ...  02-10-2020
# 2       LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ...  02-10-2020
# 3       Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ...  02-10-2020
# 4       PC All In One acer Aspire C24-960 8GB 1TB Core...  ...  02-10-2020
# ...                                                   ...  ...         ...
# 108085  Asus ROG Phone 2 12/512GB Resmi Tam Fullset Mu...  ...  27-11-2020
# 108086  ASUS ROG GL503GE # i7-8750 6CORE 120HZ 16gb SS...  ...  27-11-2020
# 108087      New Product Asus ROG F553VD, GTX1050 2GB DDr5  ...  27-11-2020
# 108088  ASUS ROG GL552VX-DM229D I7 | 8GB | 1TB | GTX 9...  ...  27-11-2020
# 108089  ASUS ROG 2 II PHONE 12GB 1TB 1 Terabyte 1000GB...  ...  27-11-2020
#
# [108090 rows x 6 columns]

# %%
# Mengganti nama kolom review menjadi sold
sold = oknov.rename(columns={'reviews': 'sold'})
sold
# Out:
#                                                      name  ...        date
# 0       ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ...  02-10-2020
# 1       Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ...  02-10-2020
# 2       LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ...  02-10-2020
# 3       Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ...  02-10-2020
# 4       PC All In One acer Aspire C24-960 8GB 1TB Core...  ...  02-10-2020
# ...                                                   ...  ...         ...
# 108085  Asus ROG Phone 2 12/512GB Resmi Tam Fullset Mu...  ...  27-11-2020
# 108086  ASUS ROG GL503GE # i7-8750 6CORE 120HZ 16gb SS...  ...  27-11-2020
# 108087      New Product Asus ROG F553VD, GTX1050 2GB DDr5  ...  27-11-2020
# 108088  ASUS ROG GL552VX-DM229D I7 | 8GB | 1TB | GTX 9...  ...  27-11-2020
# 108089  ASUS ROG 2 II PHONE 12GB 1TB 1 Terabyte 1000GB...  ...  27-11-2020
#
# [108090 rows x 6 columns]

# %%
# Menggabungkan (concatenate) dua dataframe (sold dan jan) dengan mengabaikan index
laptop = pd.concat([sold, jan], ignore_index=True, sort=False)
laptop
# Out:
#                                                      name  ...        date
# 0       ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ...  02-10-2020
# 1       Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ...  02-10-2020
# 2       LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ...  02-10-2020
# 3       Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ...  02-10-2020
# 4       PC All In One acer Aspire C24-960 8GB 1TB Core...  ...  02-10-2020
# ...                                                   ...  ...         ...
# 150683  ASUS VIVOBOOK FLIP TM420IA RYZEN 5-4500U 8GB 5...  ...  26-01-2021
# 150684  Laptop Asus Vivobook K413FQ i5 8gb 512Gb 14fhd...  ...  26-01-2021
# 150685  Asus vivobook A416ma intel N4020 4gb 256gb 14 ...  ...  26-01-2021
# 150686  ASUS VIVOBOOK A407UF I5 8250U 4GB 256GB MX130 ...  ...  26-01-2021
# 150687  LAPTOP ASUS VIVOBOOK K413EQ I7-1165G7 8GB 512G...  ...  26-01-2021
#
# [150688 rows x 6 columns]

# %% [markdown]
# ###Membersihkan dan Merapikan Data

# %% [markdown]
# ####Membersihkan karakter dari record

# %%
laptop
# Out:
#                                                      name  ...        date
# 0       ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ...  02-10-2020
# 1       Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ...  02-10-2020
# 2       LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ...  02-10-2020
# 3       Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ...  02-10-2020
# 4       PC All In One acer Aspire C24-960 8GB 1TB Core...  ...  02-10-2020
# ...                                                   ...  ...         ...
# 150683  ASUS VIVOBOOK FLIP TM420IA RYZEN 5-4500U 8GB 5...  ...  26-01-2021
# 150684  Laptop Asus Vivobook K413FQ i5 8gb 512Gb 14fhd...  ...  26-01-2021
# 150685  Asus vivobook A416ma intel N4020 4gb 256gb 14 ...  ...  26-01-2021
# 150686  ASUS VIVOBOOK A407UF I5 8250U 4GB 256GB MX130 ...  ...  26-01-2021
# 150687  LAPTOP ASUS VIVOBOOK K413EQ I7-1165G7 8GB 512G...  ...  26-01-2021
#
# [150688 rows x 6 columns]

# %%
#Memeriksa tipe data
laptop.dtypes
# Out:
# name        object
# price       object
# location    object
# sold        object
# link        object
# date        object
# dtype: object

# %%
lap = laptop
lap
# Out:
#                                                      name  ...        date
# 0       ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ...  02-10-2020
# 1       Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ...  02-10-2020
# 2       LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ...  02-10-2020
# 3       Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ...  02-10-2020
# 4       PC All In One acer Aspire C24-960 8GB 1TB Core...  ...  02-10-2020
# ...                                                   ...  ...         ...
# 150683  ASUS VIVOBOOK FLIP TM420IA RYZEN 5-4500U 8GB 5...  ...  26-01-2021
# 150684  Laptop Asus Vivobook K413FQ i5 8gb 512Gb 14fhd...  ...  26-01-2021
# 150685  Asus vivobook A416ma intel N4020 4gb 256gb 14 ...  ...  26-01-2021
# 150686  ASUS VIVOBOOK A407UF I5 8250U 4GB 256GB MX130 ...  ...  26-01-2021
# 150687  LAPTOP ASUS VIVOBOOK K413EQ I7-1165G7 8GB 512G...  ...  26-01-2021
#
# [150688 rows x 6 columns]

# %%
# menghilangkan . dari kolom price
lap['price'] = lap['price'].str.replace('.', '')
lap
# Out:
#                                                      name  ...        date
# 0       ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ...  02-10-2020
# 1       Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ...  02-10-2020
# 2       LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ...  02-10-2020
# 3       Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ...  02-10-2020
# 4       PC All In One acer Aspire C24-960 8GB 1TB Core...  ...  02-10-2020
# ...                                                   ...  ...         ...
# 150683  ASUS VIVOBOOK FLIP TM420IA RYZEN 5-4500U 8GB 5...  ...  26-01-2021
# 150684  Laptop Asus Vivobook K413FQ i5 8gb 512Gb 14fhd...  ...  26-01-2021
# 150685  Asus vivobook A416ma intel N4020 4gb 256gb 14 ...  ...  26-01-2021
# 150686  ASUS VIVOBOOK A407UF I5 8250U 4GB 256GB MX130 ...  ...  26-01-2021
# 150687  LAPTOP ASUS VIVOBOOK K413EQ I7-1165G7 8GB 512G...  ...  26-01-2021
#
# [150688 rows x 6 columns]

# %%
# menghilangkan - dari kolom date
lap['date'] = lap['date'].str.replace('-', '')
lap.head()
# Out:
#                                                 name  ...      date
# 0  ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ...  02102020
# 1  Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ...  02102020
# 2  LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ...  02102020
# 3  Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ...  02102020
# 4  PC All In One acer Aspire C24-960 8GB 1TB Core...  ...  02102020
#
# [5 rows x 6 columns]

# %% [markdown]
# ####Mengubah Tipe Data

# %%
#mengubah tipe data kolom date menjadi datetime
lap['date'] = pd.to_datetime(lap['date'], format='%d%m%Y')
lap.head()
# Out:
#                                                 name  ...       date
# 0  ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ... 2020-10-02
# 1  Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ... 2020-10-02
# 2  LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ... 2020-10-02
# 3  Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ... 2020-10-02
# 4  PC All In One acer Aspire C24-960 8GB 1TB Core...  ... 2020-10-02
#
# [5 rows x 6 columns]

# %%
#Mengubah tipe data kolom price menjadi numeric
lap['price'] = pd.to_numeric(lap['price'])
lap.head()
# Out:
#                                                 name  ...       date
# 0  ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ... 2020-10-02
# 1  Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ... 2020-10-02
# 2  LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ... 2020-10-02
# 3  Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ... 2020-10-02
# 4  PC All In One acer Aspire C24-960 8GB 1TB Core...  ... 2020-10-02
#
# [5 rows x 6 columns]

# %%
lap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150688 entries, 0 to 150687
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   name      150688 non-null  object
#  1   price     150688 non-null  int64
#  2   location  150688 non-null  object
#  3   sold      150688 non-null  object
#  4   link      150688 non-null  object
#  5   date      150688 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 6.9+ MB

# %%
df = lap.copy(deep=True)
df
# Out:
#                                                      name  ...       date
# 0       ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ... 2020-10-02
# 1       Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ... 2020-10-02
# 2       LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ... 2020-10-02
# 3       Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ... 2020-10-02
# 4       PC All In One acer Aspire C24-960 8GB 1TB Core...  ... 2020-10-02
# ...                                                   ...  ...        ...
# 150683  ASUS VIVOBOOK FLIP TM420IA RYZEN 5-4500U 8GB 5...  ... 2021-01-26
# 150684  Laptop Asus Vivobook K413FQ i5 8gb 512Gb 14fhd...  ... 2021-01-26
# 150685  Asus vivobook A416ma intel N4020 4gb 256gb 14 ...  ... 2021-01-26
# 150686  ASUS VIVOBOOK A407UF I5 8250U 4GB 256GB MX130 ...  ... 2021-01-26
# 150687  LAPTOP ASUS VIVOBOOK K413EQ I7-1165G7 8GB 512G...  ... 2021-01-26
#
# [150688 rows x 6 columns]

# %%
# Memeriksa apakah dalam kolom ada string tertentu
boolean_findings = df['sold'].str.contains('rb')
total_occurence = boolean_findings.sum()  # Returns count of all boolean true.
if(total_occurence > 0):
    print("Yes the string is present in the column. Total", total_occurence)
# Out:
# Yes the string is present in the column. Total 14

# %%
filter = df[df['sold'].str.contains('rb', na=False)]
filter
# Out:
#                                                      name  ...       date
# 109159  Laptop Lenovo Ideapad 130 Amd A4 9125 4GB 500G...  ... 2021-01-28
# 109867  Laptop Lenovo Ideapad 130 Amd A4 9125 4GB 500G...  ... 2021-01-25
# 116843  Laptop Lenovo Ideapad 130 Amd A4 9125 4GB 500G...  ... 2021-01-18
# 119732  Laptop Lenovo Ideapad 130 Amd A4 9125 4GB 500G...  ... 2021-01-29
# 123296  Laptop Lenovo Ideapad 130 Amd A4 9125 4GB 500G...  ... 2021-01-23
# 127916  Laptop Lenovo Ideapad 130 Amd A4 9125 4GB 500G...  ... 2021-01-26
# 128457  Laptop Dell 6410 Core i5 - Super murah - Berga...  ... 2021-01-20
# 134996  Laptop Dell 6410 Core i5 - Super murah - Berga...  ... 2021-01-20
# 135727  Laptop Lenovo Ideapad 130 Amd A4 9125 4GB 500G...  ... 2021-01-29
# 135935  Laptop Lenovo Ideapad 130 Amd A4 9125 4GB 500G...  ... 2021-01-28
# 136355  Laptop Lenovo Ideapad 130 Amd A4 9125 4GB 500G...  ... 2021-01-26
# 136567  Laptop Lenovo Ideapad 130 Amd A4 9125 4GB 500G...  ... 2021-01-25
# ...

# %%
df['sold']= df['sold'].replace('1,0 rb', 1000)

# %%
# Memeriksa apakah dalam kolom ada string tertentu
boolean_findings = df['sold'].str.contains('rb')
total_occurence = boolean_findings.sum()  # Returns count of all boolean true.
if(total_occurence > 0):
    print("Yes the string is present in the column. Total", total_occurence)
# Out:
# Yes the string is present in the column. Total 2

# %%
filter2 = df[df['sold'].str.contains('rb', na=False)]
filter2
# Out:
#                                                      name  ...       date
# 128457  Laptop Dell 6410 Core i5 - Super murah - Berga...  ... 2021-01-20
# 134996  Laptop Dell 6410 Core i5 - Super murah - Berga...  ... 2021-01-20
#
# [2 rows x 6 columns]

# %%
df['sold']= df['sold'].replace('1,1 rb', 1100)

# %%
# Memeriksa apakah dalam kolom ada string tertentu
boolean_findings = df['sold'].str.contains('rb')
total_occurence = boolean_findings.sum()  # Returns count of all boolean true.
if(total_occurence >= 0):
    print("Yes the string is present in the column. Total", total_occurence)
# Out:
# Yes the string is present in the column. Total 0

# %%
df
# Out:
#                                                      name  ...       date
# 0       ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ... 2020-10-02
# 1       Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ... 2020-10-02
# 2       LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ... 2020-10-02
# 3       Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ... 2020-10-02
# 4       PC All In One acer Aspire C24-960 8GB 1TB Core...  ... 2020-10-02
# ...                                                   ...  ...        ...
# 150683  ASUS VIVOBOOK FLIP TM420IA RYZEN 5-4500U 8GB 5...  ... 2021-01-26
# 150684  Laptop Asus Vivobook K413FQ i5 8gb 512Gb 14fhd...  ... 2021-01-26
# 150685  Asus vivobook A416ma intel N4020 4gb 256gb 14 ...  ... 2021-01-26
# 150686  ASUS VIVOBOOK A407UF I5 8250U 4GB 256GB MX130 ...  ... 2021-01-26
# 150687  LAPTOP ASUS VIVOBOOK K413EQ I7-1165G7 8GB 512G...  ... 2021-01-26
#
# [150688 rows x 6 columns]

# %%
#Mengubah tipe data kolom sold menjadi numeric
df['sold'] = pd.to_numeric(df['sold'])
df.head()
# Out:
#                                                 name  ...       date
# 0  ACER ASPIRE 3 A314 - INTEL CELERON N4000 - 14 ...  ... 2020-10-02
# 1  Laptop Acer Aspire 3 Celeron N4120 256GB SSD 4...  ... 2020-10-02
# 2  LAPTOP ACER ASPIRE 3 A314-21 A4 9120e RAM 4GB ...  ... 2020-10-02
# 3  Acer Aspire 3 A314 A4 9120 4GB 1TB W10 14.0 DV...  ... 2020-10-02
# 4  PC All In One acer Aspire C24-960 8GB 1TB Core...  ... 2020-10-02
#
# [5 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150688 entries, 0 to 150687
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   name      150688 non-null  object
#  1   price     150688 non-null  int64
#  2   location  150688 non-null  object
#  3   sold      150688 non-null  int64
#  4   link      150688 non-null  object
#  5   date      150688 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 6.9+ MB

# %%
#Pilih direktori Tokped
os.chdir("/content/drive/My Drive/Dataset/Laptop_Price_List_Tokopedia/Tokped")

# %%
df.to_csv('tokped_clean_data.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Mengurai data

# %%
#Menambahkan kolom kategori laptop berdasarkan kolom name yang mengandung sebagian string
cond_list = [laptop['name'].str.contains('acer', case=False),
             laptop['name'].str.contains('asus', case=False),
             laptop['name'].str.contains('dell', case=False),
             laptop['name'].str.contains('hp', case=False),
             laptop['name'].str.contains('lenovo', case=False),
             laptop['name'].str.contains('msi', case=False)]
choice_list = ['Acer', 'Asus', 'Dell', 'HP', 'Lenovo', 'MSI']

laptop['Category'] = np.select(cond_list, choice_list)
laptop.head()
# Out:
#                                                 name  ...  Category
# 0  Laptop Asus Vivobook A416JA BV311TS i3 1005G1 ...  ...      Asus
# 1  Asus Vivobook K413EQ GeForce® MX350 - i7 1165G...  ...      Asus
# 2  ASUS Vivobook A416JA BV311TS i3 1005G1 4G 1TB ...  ...      Asus
# 3  Asus Vivobook K413EQ 14" FHD Core i7-1165G7 8G...  ...      Asus
# 4  LAPTOP ASUS VIVOBOOK K413FQ i5-10210U 8GB 512G...  ...      Asus
#
# [5 rows x 7 columns]

# %% [markdown]
# ##Memvisualisasikan Data

# %%
laptop
# Out:
#                                                     name  ...  Category
# 0      Laptop Asus Vivobook A416JA BV311TS i3 1005G1 ...  ...      Asus
# 1      Asus Vivobook K413EQ GeForce® MX350 - i7 1165G...  ...      Asus
# 2      ASUS Vivobook A416JA BV311TS i3 1005G1 4G 1TB ...  ...      Asus
# 3      Asus Vivobook K413EQ 14" FHD Core i7-1165G7 8G...  ...      Asus
# 4      LAPTOP ASUS VIVOBOOK K413FQ i5-10210U 8GB 512G...  ...      Asus
# ...                                                  ...  ...       ...
# 42593  ASUS VIVOBOOK FLIP TM420IA RYZEN 5-4500U 8GB 5...  ...      Asus
# 42594  Laptop Asus Vivobook K413FQ i5 8gb 512Gb 14fhd...  ...      Asus
# 42595  Asus vivobook A416ma intel N4020 4gb 256gb 14 ...  ...      Asus
# 42596  ASUS VIVOBOOK A407UF I5 8250U 4GB 256GB MX130 ...  ...      Asus
# 42597  LAPTOP ASUS VIVOBOOK K413EQ I7-1165G7 8GB 512G...  ...      Asus
#
# [42598 rows x 7 columns]

# %%
laptop.value_counts('Category')
# Out:
# Category
# Lenovo    13398
# Asus      13194
# Acer       5902
# HP         3532
# Dell       3290
# MSI        2436
# 0           846
# dtype: int64

# %%
sold_mean = laptop.groupby(['location', 'date']).agg({'sold': np.sum})
sold_mean = sold_mean.reset_index()
print(sold_mean)
# Out:
#            location       date  sold
# 0    Bandar Lampung 2021-01-14     4
# 1    Bandar Lampung 2021-01-15    55
# 2    Bandar Lampung 2021-01-16     2
# 3    Bandar Lampung 2021-01-18    53
# 4    Bandar Lampung 2021-01-19    52
# ..              ...        ...   ...
# 556      Yogyakarta 2021-01-25    19
# 557      Yogyakarta 2021-01-26    16
# 558      Yogyakarta 2021-01-27     4
# 559      Yogyakarta 2021-01-28     6
# 560      Yogyakarta 2021-01-29     5
#
# [561 rows x 3 columns]

# %%
grouped = sold_mean.groupby('date')

ncols=2
nrows = int(np.ceil(grouped.ngroups/ncols))

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12,32), sharey=True)
#plt.tight_layout()
fig.subplots_adjust(hspace=2)

for (key, ax) in zip(grouped.groups.keys(), axes.flatten()):
    grouped.get_group(key).plot(x='location', y='sold', ax=ax)
    ax.set_title("Tanggal {}".format(key))
    #ax.xaxis.set_tick_params(labelbottom=True)
    #ax.yaxis.set_tick_params(labelleft=True)
    #ax.set_xticks(np.arange(len(x)))
    
ax.legend(loc = 'best')
#plt.savefig('./dataset/baru/test.png')
plt.show()

# %%
# menampilkan grafik total jumlah penumpang dari setiap kereta pada setiap stasiun
grouped = sold_mean.groupby(['date'])
fig, ax = plt.subplots(figsize=(16,8))
for key, group in grouped:
    group['sold'].plot(label=key, ax=ax)

plt.legend(loc='best')
#plt.savefig('./dataset/baru/test2.png')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['agg.path.chunksize'] = 10000
# %matplotlib inline

# menampilkan grafik total jumlah penumpang dari setiap kereta pada setiap stasiun
grouped = laptop.groupby(['date'])
fig, ax = plt.subplots(figsize=(16,8))
for key, group in grouped:
    group['sold'].plot(label=key, ax=ax)

plt.legend(loc='best')
#plt.savefig('./dataset/baru/test2.png')
plt.show()
